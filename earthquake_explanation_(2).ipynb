# %% [markdown]
# <a href="https://colab.research.google.com/github/ankithag235/assignment--1/blob/main/earthquake_explanation_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌍 Earthquake Data Extraction

# %% [markdown]
# ## ⭐ 1. Importing Libraries
# We start by importing the required Python libraries.

# %%
import requests
import pandas as pd
from datetime import datetime

# %% [markdown]
# ## ⭐ 2. API URL — What is this?
# USGS provides free earthquake data using a web API.
#
# ``url = "https://earthquake.usgs.gov/fdsnws/event/1/query"``
# This is **not an API key**, it is simply the **endpoint URL** for querying earthquake events.

# %%
url = "https://earthquake.usgs.gov/fdsnws/event/1/query"

# %% [markdown]
# ## ⭐ 3. Preparing Variables
# We store all earthquake records in a list and choose a date range (last 5 years).

# %%
all_records = []
start_year = datetime.now().year - 5
end_year = datetime.now().year

# %% [markdown]
# ## ⭐ 4. Looping Through Years and Months
# We query month-by-month because datasets are huge and may fail if requested all at once.
#
# For each year (e.g., 2020 → 2025)
# For each month (01 → 12)
# We build the **starttime** and **endtime** for API filters.

# %%
for year in range(start_year, end_year + 1):
    for month in range(1, 13):

        start_date = f"{year}-{month:02d}-01"

        if month == 12:
            end_date = f"{year+1}-01-01"
        else:
            end_date = f"{year}-{month+1:02d}-01"

        print(start_date, "→", end_date)  # Demo only
# Out:
# 2020-01-01 → 2020-02-01
# 2020-02-01 → 2020-03-01
# 2020-03-01 → 2020-04-01
# 2020-04-01 → 2020-05-01
# 2020-05-01 → 2020-06-01
# 2020-06-01 → 2020-07-01
# 2020-07-01 → 2020-08-01
# 2020-08-01 → 2020-09-01
# 2020-09-01 → 2020-10-01
# 2020-10-01 → 2020-11-01
# 2020-11-01 → 2020-12-01
# 2020-12-01 → 2021-01-01
# 2021-01-01 → 2021-02-01
# 2021-02-01 → 2021-03-01
# 2021-03-01 → 2021-04-01
# 2021-04-01 → 2021-05-01
# 2021-05-01 → 2021-06-01
# 2021-06-01 → 2021-07-01
# 2021-07-01 → 2021-08-01
# 2021-08-01 → 2021-09-01
# 2021-09-01 → 2021-10-01
# 2021-10-01 → 2021-11-01
# 2021-11-01 → 2021-12-01
# 2021-12-01 → 2022-01-01
# 2022-01-01 → 2022-02-01
# 2022-02-01 → 2022-03-01
# 2022-03-01 → 2022-04-01
# 2022-04-01 → 2022-05-01
# 2022-05-01 → 2022-06-01
# 2022-06-01 → 2022-07-01
# 2022-07-01 → 2022-08-01
# 2022-08-01 → 2022-09-01
# 2022-09-01 → 2022-10-01
# 2022-10-01 → 2022-11-01
# 2022-11-01 → 2022-12-01
# 2022-12-01 → 2023-01-01
# 2023-01-01 → 2023-02-01
# 2023-02-01 → 2023-03-01
# 2023-03-01 → 2023-04-01
# 2023-04-01 → 2023-05-01
# 2023-05-01 → 2023-06-01
# 2023-06-01 → 2023-07-01
# 2023-07-01 → 2023-08-01
# 2023-08-01 → 2023-09-01
# 2023-09-01 → 2023-10-01
# 2023-10-01 → 2023-11-01
# 2023-11-01 → 2023-12-01
# 2023-12-01 → 2024-01-01
# 2024-01-01 → 2024-02-01
# 2024-02-01 → 2024-03-01
# 2024-03-01 → 2024-04-01
# 2024-04-01 → 2024-05-01
# 2024-05-01 → 2024-06-01
# 2024-06-01 → 2024-07-01
# 2024-07-01 → 2024-08-01
# 2024-08-01 → 2024-09-01
# 2024-09-01 → 2024-10-01
# 2024-10-01 → 2024-11-01
# 2024-11-01 → 2024-12-01
# 2024-12-01 → 2025-01-01
# 2025-01-01 → 2025-02-01
# 2025-02-01 → 2025-03-01
# 2025-03-01 → 2025-04-01
# 2025-04-01 → 2025-05-01
# 2025-05-01 → 2025-06-01
# 2025-06-01 → 2025-07-01
# 2025-07-01 → 2025-08-01
# 2025-08-01 → 2025-09-01
# 2025-09-01 → 2025-10-01
# 2025-10-01 → 2025-11-01
# 2025-11-01 → 2025-12-01
# 2025-12-01 → 2026-01-01

# %% [markdown]
# ## ⭐ 5. Parameters Sent to the API
# We pass filters such as:
#
# - **format=geojson** → Ask data in GeoJSON
# - **starttime, endtime** → Date range
# - **minmagnitude=3** → Only earthquakes above magnitude 3
#
# These become query parameters.

# %%
params = {
    "format": "geojson",
    "starttime": "2024-01-01",
    "endtime": "2024-02-01",
    "minmagnitude": 3
}

print(params)
# Out:
# {'format': 'geojson', 'starttime': '2024-01-01', 'endtime': '2024-02-01', 'minmagnitude': 3}

# %%
url = "https://earthquake.usgs.gov/fdsnws/event/1/query"

# %% [markdown]
# ## ⭐ 6. Sending the API Request
# `requests.get(url, params=params)` fetches the data.
# If the request fails, we print a warning.

# %%
response = requests.get(url, params=params)

if response.status_code != 200:
    print("Request failed:", response.text[:200])
else:
    print("Success!")
# Out:
# Success!

# %%
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# ## ⭐ 7. Reading JSON Data
# USGS responds with JSON containing:
# - **metadata**
# - **features** → list of earthquake events
#
# Each feature has:
# - **properties** → magnitude, time, place, etc.
# - **geometry** → latitude, longitude, depth

# %%
print(data)
# Out:
# {'type': 'FeatureCollection', 'metadata': {'generated': 1764299158000, 'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2024-01-01&endtime=2024-02-01&minmagnitude=3', 'title': 'USGS Earthquakes', 'status': 200, 'api': '1.14.1', 'count': 1734}, 'features': [{'type': 'Feature', 'properties': {'mag': 4.6, 'place': '97 km S of La Libertad, El Salvador', 'time': 1706744597478, 'updated': 1713036656040, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lvj9', 'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000lvj9&format=geojson', 'felt': None, 'cdi': None, 'mmi': None, 'alert': None, 'status': 'reviewed', 'tsunami': 0, 'sig': 326, 'net': 'us', 'code': '7000lvj9', 'ids': ',us7000lvj9,', 'sources': ',us,', 'types': ',origin,phase-data,', 'nst': 98, 'dmin': 1.049, 'rms': 0.57, 'gap': 163, 'magType': 'mb', 'type': 'earthquake', 'title': 'M 4.6 - 97 km S of La Libertad, El Salvador'}, 'geometry': {'type': 'Point', 'coordinates': [-89.2963, 12.6093, 45.259]}, 'id': 'us7000lvj9'}, {'type': 'Feature', 'properties': {'mag': 4.2, 'place': '18 km NNW of Anamizu, Japan', 'time': 1706742432081, 'updated': 1713036654040, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lviq', 'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000lviq&format=geojson', 'felt': None, 'cdi': None, 'mmi': None, 'alert': None, 'status': 'reviewed', 'tsunami': 0, 'sig': 271, 'net': 'us', 'code': '7000lviq', 'ids': ',us7000lviq,', 'sources': ',us,', 'types': ',moment-tensor,origin,phase-data,', 'nst': 67, 'dmin': 1.341, 'rms': 0.68, 'gap': 65, 'magType': 'mwr', 'type': 'earthquake', 'title': 'M 4.2 - 18 km NNW of Anamizu, Japan'}, 'geometry': {'type': 'Point', 'coordinates': [136.7898, 37.3723, 8.748]}, 'id': 'us7000lviq'}, {'type': 'Feature', 'properties': {'mag': 4.4, 'place': 'northern Mid-Atlantic Ridge', 'time': 1706741512816, 'updated': 1713036653040, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lx42', 'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000lx42&format=geojson', 'felt': None, 'cdi': None, 'mmi': None, 'alert': None, 'status': 'reviewed', 'tsunami': 0, 'sig': 298, 'net': 'us', 'code': '7000lx42', 'ids': ',us7000lx42,', 'sources': ',us,', 'types': ',origin,phase-data,', 'nst': 21, 'dmin': 21.018, 'rms': 0.64, 'gap': 97, 'magType': 'mb', 'type': 'earthquake', 'title': 'M 4.4 - northern Mid-Atlantic Ridge'}, 'geometry': {'type': 'Point', 'coordinates': [-39.3618, 33.1068, 10]}, 'id': 'us7000lx42'}, {'type': 'Feature', 'properties': {'mag': 4.5, 'place': '51 km SSE of Finschhafen, Papua New Guinea', 'time': 1706740136022, 'updated': 1713036650040, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lx41', 'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000lx41&format=geojson', 'felt': None, 'cdi': None, 'mmi': None, 'alert': None, 'status': 'reviewed', 'tsunami': 0, 'sig': 312, 'net': 'us', 'code': '7000lx41', 'ids': ',us7000lx41,', 'sources': ',us,', 'types': ',origin,phase-data,', 'nst': 49, 'dmin': 2.59, 'rms': 0.58, 'gap': 134, 'magType': 'mb', 'type': 'earthquake', 'title': 'M 4.5 - 51 km SSE of Finschhafen, Papua New Guinea'}, 'geometry': {'type': 'Point', 'coordinates': [148.0811, -6.9643, 28.439]}, 'id': 'us7000lx41'}, {'type': 'Feature', 'properties': {'mag': 4.3, 'place': 'southeast of the Loyalty Islands', 'time': 1706738664814, 'updated': 1713036646040, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lx43', 'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000lx43&format=geojson', 'felt': None, 'cdi': None, 'mmi': None, 'alert': None, 'status': 'reviewed', 'tsunami': 0, 'sig': 284, 'net': 'us', 'code': '7000lx43', 'ids': ',us7000lx43,', 'sources': ',us,', 'types': ',origin,phase-data,', 'nst': 17, 'dmin': 4.533, 'rms': 0.9, 'gap': 156, 'magType': 'mb', 'type': 'earthquake ...
